# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
F1_T1=pd.read_excel('Data 2016.XLSX',sheet_name='Table 1',skiprows=1)

# %%
F1_T1
# Out:
#               State            City  \
# 0    Andhra Pradesh       Anantapur
# 1               NaN         Chitoor
# 2               NaN             NaN
# 3               NaN           Eluru
# 4               NaN          Guntur
# ..              ...             ...
# 575             NaN             NaN
# 576             NaN             NaN
# 577             NaN  South Suburban
# 578             NaN             NaN
# 579             NaN             NaN
#
#                                              Location  \
# 0                                        Kamala Nagar
# 1                              GNC Toll Gate Tirumala
# 2    Near M/s. Nutrine Confectionery,\nPalamaner Road
# 3                         At Ashram Diagnostic Centre
# 4                     Near Hindu College, Market Road
# ..                                                ...
# 575                           Dhulagar  Gram Pachayat
# 576               P Mukherjee's House, Near SBI\nAmta
# ...

# %%
F1_T1.drop('Unnamed: 7',inplace=True,axis=1)

# %%
pd.options.display.max_rows =None
F1_T1[0:]
# Out:
#                      State                 City  \
# 0           Andhra Pradesh            Anantapur
# 1                      NaN              Chitoor
# 2                      NaN                  NaN
# 3                      NaN                Eluru
# 4                      NaN               Guntur
# 5                      NaN               Kadapa
# 6                      NaN             Kakinada
# 7                      NaN              Kurnool
# 8                      NaN              Nellore
# 9                      NaN             Prakasam
# 10                     NaN          Rajahmundry
# 11                     NaN           Srikakulam
# 12                     NaN             Tirupati
# 13                     NaN            Vijaywada
# 14                     NaN                  NaN
# 15                     NaN                  NaN
# 16                     NaN       Vishakhapatnam
# 17                     NaN                  NaN
# ...

# %%
F1_T1.iloc[:,0]
# Out:
# 0      Andhra Pradesh
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 575               NaN
# 576               NaN
# 577               NaN
# 578               NaN
# 579               NaN
# Name: State, Length: 580, dtype: object

# %%
states_list=[]
for i in range(len(F1_T1.iloc[:,0])):
    if type(F1_T1.iloc[:,0][i]) == str:

        states_list.append(F1_T1.iloc[:,0][i])
        
ind.append(len(F1_T1))

# %%
states_list
# Out:
# ['Andhra Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Dadra &\nNagar Haveli',
#  'Daman &\nDiu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamilnadu',
#  'Telangana',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
F1_T1.iloc[:,0][25]
# Out:
# 'Assam'

# %%
sum(F1_T1.iloc[:,6][0:25])/25
# Out:
# 6.76

# %%
#avg values
data={}
for i in range(0,len(ind)-1):
    s=sum(F1_T1.iloc[:,6][ind[i]:ind[i+1]])
    avg=s/(ind[i+1]-ind[i])
    data[states[i]] = avg

# %%
data
# Out:
# {'Andhra Pradesh': 6.76,
#  'Assam': 7.391304347826087,
#  'Bihar': 4.5,
#  'Chandigarh': 6.6923076923076925,
#  'Dadra &\nNagar Haveli': 21.0,
#  'Daman &\nDiu': 19.0,
#  'Delhi': 6.888888888888889,
#  'Goa': 5.222222222222222,
#  'Gujarat': 13.571428571428571,
#  'Himachal Pradesh': 2.3181818181818183,
#  'Jammu & Kashmir': 3.3333333333333335,
#  'Jharkhand': 21.8,
#  'Karnataka': 3.423076923076923,
#  'Kerala': 3.7916666666666665,
#  'Madhya Pradesh': 10.63888888888889,
#  'Maharashtra': 17.149253731343283,
#  'Meghalaya': 7.0,
#  'Mizoram': 2.0,
#  'Nagaland': 2.0,
#  'Orissa': 5.866666666666666,
#  'Puducherry': 9.0,
#  'Punjab': 8.125,
#  'Rajasthan': 7.233333333333333,
#  'Sikkim': 11.88888888888889,
#  'Tamilnadu': 10.741935483870968,
#  'Telangana': 5.791666666666667,
#  'Uttar Pradesh': 10.262295081967213,
#  'Uttarakhand': 25.2,
#  'West Bengal': 9.277777777777779}

# %%
f1_t1=pd.read_excel('Data 2016.XLSX',sheet_name='Table 1',skiprows=1)
f2_t1=pd.read_excel('Data 2017.XLSX',sheet_name='Table 1',skiprows=2)
f3_t1=pd.read_excel('Data 2018.XLSX',sheet_name='Table 1',skiprows=2)
f1_t1.drop('Unnamed: 7',inplace=True,axis=1)
f2_t1.drop('Unnamed: 7',inplace=True,axis=1)
f3_t1.drop('Unnamed: 7',inplace=True,axis=1)

# %%
def sp(file):
    ind=[]
    states=[]
    for i in range(len(file.iloc[:,0])):
        if type(file.iloc[:,0][i]) == str:
            ind.append(i)
            states.append(file.iloc[:,0][i])
        
    ind.append(len(file))  
    data={}
    for i in range(0,len(ind)-1):
        s=sum(file.iloc[:,6][ind[i]:ind[i+1]])
        avg=s/(ind[i+1]-ind[i])
        data[states[i]] = round(float(avg),2)
    return data

# %%
so2_2016=sp(f1_t1)
so2_2017=sp(f2_t1)
so2_2018=sp(f3_t1)

# %%
so2_2016
# Out:
# {'Andhra Pradesh': 6.76,
#  'Assam': 7.39,
#  'Bihar': 4.5,
#  'Chandigarh': 6.69,
#  'Dadra &\nNagar Haveli': 21.0,
#  'Daman &\nDiu': 19.0,
#  'Delhi': 6.89,
#  'Goa': 5.22,
#  'Gujarat': 13.57,
#  'Himachal Pradesh': 2.32,
#  'Jammu & Kashmir': 3.33,
#  'Jharkhand': 21.8,
#  'Karnataka': 3.42,
#  'Kerala': 3.79,
#  'Madhya Pradesh': 10.64,
#  'Maharashtra': 17.15,
#  'Meghalaya': 7.0,
#  'Mizoram': 2.0,
#  'Nagaland': 2.0,
#  'Orissa': 5.87,
#  'Puducherry': 9.0,
#  'Punjab': 8.12,
#  'Rajasthan': 7.23,
#  'Sikkim': 11.89,
#  'Tamilnadu': 10.74,
#  'Telangana': 5.79,
#  'Uttar Pradesh': 10.26,
#  'Uttarakhand': 25.2,
#  'West Bengal': 9.28}

# %%
so2_2017
# Out:
# {'Andhra Pradesh': 6.52,
#  'Assam': 6.7,
#  'Bihar': 9.25,
#  'Chandigarh': 6.54,
#  'Dadra & Nagar\nHaveli': 15.67,
#  'Daman & Diu': 14.33,
#  'Delhi': 7.33,
#  'Goa': 7.11,
#  'Gujarat': 14.71,
#  'Haryana': 9.5,
#  'Himachal Pradesh': 2.24,
#  'Jammu & Kashmir': 4.0,
#  'Jharkhand': 21.5,
#  'Karnataka': 3.0,
#  'Kerala': 3.75,
#  'Madhya Pradesh': 11.05,
#  'Maharashtr a': 15.43,
#  'Meghalaya': 5.2,
#  'Mizoram': 2.0,
#  'Nagaland': 2.0,
#  'Odisha': 6.43,
#  'Puducherry': 6.5,
#  'Punjab': 8.48,
#  'Rajasthan': 7.69,
#  'Sikkim': 6.12,
#  'Tamilnadu': 10.17,
#  'Telangana': 6.2,
#  'Tripura': 23.0,
#  'Uttar Pradesh': 10.62,
#  'Uttarakhan d': 8.07}

# %%
so2_2018
# Out:
# {'Andhra Pradesh': 6.46,
#  'Arunachal Pradesh': 3.0,
#  'Assam': 6.65,
#  'Bihar': 11.0,
#  'Chandigarh': 2.0,
#  'Chattisgarh': 9.44,
#  'Dadra & Nagar Haveli': 25.67,
#  'Daman & Diu': 24.0,
#  'Delhi': 6.0,
#  'Goa': 7.5,
#  'Gujarat': 17.96,
#  'Haryana': 10.0,
#  'Himachal Pradesh': 2.17,
#  'Jammu & Kashmir': 4.0,
#  'Jharkhand': 21.3,
#  'Karnataka': 3.15,
#  'Kerala': 3.62,
#  'Madhya Pradesh': 10.92,
#  'Maharashtra': 15.14,
#  'Manipur': 10.0,
#  'Meghalaya': 5.2,
#  'Mizoram': 2.0,
#  'Nagaland': 2.0,
#  'Odisha': 6.5,
#  'Puducherry': 4.0,
#  'Punjab': 7.04,
#  'Rajasthan': 8.46,
#  'Sikkim': 6.33,
#  'Tamilnadu': 10.81,
#  'Telangana': 6.56,
#  'Tripura': 11.5,
#  'Uttar Pradesh': 11.06,
#  'Uttarakhand': 19.0,
#  'West Bengal': 7.27}

# %%
f3_t1
# Out:
#                Unnamed: 0                        Unnamed: 1  \
# 0          Andhra Pradesh                         Anantapur
# 1                     NaN                               NaN
# 2                     NaN                               NaN
# 3                     NaN                               NaN
# 4                     NaN                           Chitoor
# 5                     NaN                               NaN
# 6                     NaN                               NaN
# 7                     NaN                               NaN
# 8                     NaN                             Eluru
# 9                     NaN                               NaN
# 10                    NaN                               NaN
# 11                    NaN                               NaN
# 12                    NaN                            Guntur
# 13                    NaN                               NaN
# 14                    NaN                               NaN
# ...

# %%
len(so2_2016)
# Out:
# 29

# %%
len(so2_2017)
# Out:
# 30

# %%
len(so2_2018)
# Out:
# 34

# %%
so2_2016=pd.DataFrame(so2_2016.items(),columns=['state','avg_so2'])
so2_2017=pd.DataFrame(so2_2017.items(),columns=['state','avg_so2'])
so2_2018=pd.DataFrame(so2_2018.items(),columns=['state','avg_so2'])

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_so2','state',data=so2_2016)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG SO2 IN 2016 (µg/m3)')
plt.title('2016  Average so2 in indian states(µg/m3)')
plt.savefig('./imgs/so2/2016.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_so2','state',data=so2_2017)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG SO2 IN 2017 (µg/m3)')
plt.title('2017  Average so2 in indian states (µg/m3)')
plt.savefig('./imgs/so2/2017.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_so2','state',data=so2_2018)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG SO2 IN 2018 (µg/m3)')
plt.title('2018  Average so2 in indian states (µg/m3)')
plt.savefig('./imgs/so2/2018.jpg',bbox_inches='tight')

# %%
f1_t2=pd.read_excel('Data 2016.XLSX',sheet_name='Table 2',skiprows=1)
f2_t2=pd.read_excel('Data 2017.XLSX',sheet_name='Table 2',skiprows=2)
f3_t2=pd.read_excel('Data 2018.XLSX',sheet_name='Table 2',skiprows=2)
f1_t2.drop('Unnamed: 7',inplace=True,axis=1)
f2_t2.drop('Unnamed: 7',inplace=True,axis=1)
f3_t2.drop('Unnamed: 7',inplace=True,axis=1)

no2_2016=sp(f1_t2)
no2_2017=sp(f2_t2)
no2_2018=sp(f3_t2)

no2_2016=pd.DataFrame(no2_2016.items(),columns=['state','avg_no2'])
no2_2017=pd.DataFrame(no2_2017.items(),columns=['state','avg_no2'])
no2_2018=pd.DataFrame(no2_2018.items(),columns=['state','avg_no2'])

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_no2','state',data=no2_2016)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG NO2 IN 2016 (µg/m3)')
plt.title('2016  Average no2 in indian states (µg/m3)')
plt.savefig('./imgs/no2/2016.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_no2','state',data=no2_2017)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG NO2 IN 2017 (µg/m3)')
plt.title('2017  Average no2 in indian states (µg/m3)')
plt.savefig('./imgs/no2/2017.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_no2','state',data=no2_2018)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG NO2 IN 2018 (µg/m3)')
plt.title('2018  Average no2 in indian states (µg/m3)')
plt.savefig('./imgs/no2/2018.jpg',bbox_inches='tight')

# %%
f1_t3=pd.read_excel('Data 2016.XLSX',sheet_name='Table 3',skiprows=1)
f2_t3=pd.read_excel('Data 2017.XLSX',sheet_name='Table 3',skiprows=2)
f3_t3=pd.read_excel('Data 2018.XLSX',sheet_name='Table 3',skiprows=2)
f1_t3.drop('Unnamed: 7',inplace=True,axis=1)
f2_t3.drop('Unnamed: 7',inplace=True,axis=1)
f3_t3.drop('Unnamed: 7',inplace=True,axis=1)
pm10_2016=sp(f1_t3)
pm10_2017=sp(f2_t3)
pm10_2018=sp(f3_t3)

pm10_2016=pd.DataFrame(pm10_2016.items(),columns=['state','avg_pm10'])
pm10_2017=pd.DataFrame(pm10_2017.items(),columns=['state','avg_pm10'])
pm10_2018=pd.DataFrame(pm10_2018.items(),columns=['state','avg_pm10'])

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_pm10','state',data=pm10_2016)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG Particulate Matter (≤10 µg/m3) IN 2016')
plt.title('2016  Average Particulate Matter (≤10 µg/m3) in indian states')
plt.savefig('./imgs/pm10/2016.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_pm10','state',data=pm10_2017)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG Particulate Matter (≤10 µg/m3) IN 2017')
plt.title('2017  Average Particulate Matter (≤10 µg/m3) in indian states')
plt.savefig('./imgs/pm10/2017.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_pm10','state',data=pm10_2018)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG Particulate Matter (≤10 µg/m3) IN 2018')
plt.title('2018  Average Particulate Matter (≤10 µg/m3) in indian states')
plt.savefig('./imgs/pm10/2018.jpg',bbox_inches='tight')

# %%
f1_t4=pd.read_excel('Data 2016.XLSX',sheet_name='Table 4',skiprows=1)
f2_t4=pd.read_excel('Data 2017.XLSX',sheet_name='Table 4',skiprows=2)
f3_t4=pd.read_excel('Data 2018.XLSX',sheet_name='Table 4',skiprows=2)
f1_t4.drop('Unnamed: 7',inplace=True,axis=1)
f2_t4.drop('Unnamed: 7',inplace=True,axis=1)
f3_t4.drop('Unnamed: 7',inplace=True,axis=1)
pm2_5_2016=sp(f1_t4)
pm2_5_2017=sp(f2_t4)
pm2_5_2018=sp(f3_t4)

pm2_5_2016=pd.DataFrame(pm2_5_2016.items(),columns=['state','avg_pm2.5'])
pm2_5_2017=pd.DataFrame(pm2_5_2017.items(),columns=['state','avg_pm2.5'])
pm2_5_2018=pd.DataFrame(pm2_5_2018.items(),columns=['state','avg_pm2.5'])

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_pm2.5','state',data=pm2_5_2016)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG Particulate Matter (≤2.5µg/m3) IN 2016')
plt.title('2016  Average Particulate Matter (≤2.5µg/m3) in indian states')
plt.savefig('./imgs/pm2.5/2016.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_pm2.5','state',data=pm2_5_2017)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG Particulate Matter (≤2.5µg/m3) IN 2017')
plt.title('2017  Average Particulate Matter (≤2.5µg/m3) in indian states')
plt.savefig('./imgs/pm2.5/2017.jpg',bbox_inches='tight')

# %%
plt.figure(figsize=(8,10))
sns.barplot('avg_pm2.5','state',data=pm2_5_2018)
plt.grid(axis='x',color='lightgreen', linestyle='--', linewidth=1)
plt.ylabel('STATES')
plt.xlabel('AVG Particulate Matter (≤2.5µg/m3) IN 2018')
plt.title('2018  Average Particulate Matter (≤2.5µg/m3) in indian states')
plt.savefig('./imgs/pm2.5/2018.jpg',bbox_inches='tight')

# %%
plt.figure()
plt.scatter(np.array(so2_2016['avg_so2']),np.array(no2_2016['avg_no2']))
plt.show()

# %%
sns.scatterplot(x=so2_2016['avg_so2'],y=so2_2017['avg_so2'])

# %% [markdown]
# # 2016

# %%
dataframe2016=pd.concat([so2_2016,no2_2016['avg_no2'],pm2_5_2016['avg_pm2.5'],pm10_2016['avg_pm10']],axis=1)

# %%
dataframe2016
# Out:
#                     state  avg_so2  avg_no2  avg_pm2.5  avg_pm10
# 0          Andhra Pradesh     6.76    22.92     123.40     76.04
# 1                   Assam     7.39    15.57      73.00     83.96
# 2                   Bihar     4.50    32.00     109.50    211.50
# 3              Chandigarh     6.69    22.54      29.72    108.08
# 4   Dadra &\nNagar Haveli    21.00    32.00      32.24     37.00
# 5            Daman &\nDiu    19.00    29.00      43.42     34.00
# 6                   Delhi     6.89    66.89      37.83    276.11
# 7                     Goa     5.22    10.89      41.04     69.61
# 8                 Gujarat    13.57    24.57      30.36    100.57
# 9        Himachal Pradesh     2.32    12.77      47.14     80.09
# 10        Jammu & Kashmir     3.33    17.00      67.56    131.00
# 11              Jharkhand    21.80    37.80        NaN    180.60
# 12              Karnataka     3.42    20.85        NaN     80.08
# ...

# %%
sns.heatmap(data=dataframe2016.iloc[0:29,1:5])

# %%
dataframe2016.corr()
# Out:
#             avg_so2   avg_no2  avg_pm2.5  avg_pm10
# avg_so2    1.000000  0.394000  -0.390812  0.013713
# avg_no2    0.394000  1.000000  -0.124435  0.589606
# avg_pm2.5 -0.390812 -0.124435   1.000000  0.158876
# avg_pm10   0.013713  0.589606   0.158876  1.000000

# %%
dataframe2017=pd.concat([so2_2017,no2_2017['avg_no2'],pm2_5_2017['avg_pm2.5'],pm10_2017['avg_pm10']],axis=1)

# %%
dataframe2017.corr()
# Out:
#             avg_so2   avg_no2  avg_pm2.5  avg_pm10
# avg_so2    1.000000  0.353854   0.197290  0.241652
# avg_no2    0.353854  1.000000  -0.107857  0.446903
# avg_pm2.5  0.197290 -0.107857   1.000000 -0.257886
# avg_pm10   0.241652  0.446903  -0.257886  1.000000

# %%
dataframe2018=pd.concat([so2_2018,no2_2018['avg_no2'],pm2_5_2018['avg_pm2.5'],pm10_2018['avg_pm10']],axis=1)

# %%
dataframe2018.corr()
# Out:
#             avg_so2   avg_no2  avg_pm2.5  avg_pm10
# avg_so2    1.000000  0.373651   0.170944  0.349274
# avg_no2    0.373651  1.000000  -0.230858  0.510890
# avg_pm2.5  0.170944 -0.230858   1.000000 -0.279724
# avg_pm10   0.349274  0.510890  -0.279724  1.000000
